# %%
import os
import re
from pathlib import Path
import shutil

def get_markdown_files(root_dir):
    """Recursively find all markdown files excluding .gitbook directory"""
    for root, dirs, files in os.walk(root_dir):
        if '.gitbook' in dirs:
            dirs.remove('.gitbook')
        
        for file in files:
            if file.endswith('.md'):
                yield os.path.join(root, file)

def process_markdown_file(md_file):
    """Process a single markdown file and return required image replacements"""
    with open(md_file, 'r', encoding='utf-8') as f:
        content = f.read()
    
    base_name = os.path.splitext(os.path.basename(md_file))[0].replace('-', '_')
    
    # Updated pattern to match complete figure tags
    pattern = r'<figure><img src="(.*?\.png)".*?></figure>'
    matches = re.finditer(pattern, content)
    
    replacements = []
    for idx, match in enumerate(matches, 1):
        old_path = match.group(1)
        # Store markdown file for error reporting
        replacements.append((old_path, base_name, f"{base_name}_{idx}.png", md_file))
        
        # Determine if we need ../ or ../../ based on the original path
        dots = "../../" if old_path.startswith("../../") else "../"
        
        # Create complete replacement with proper GitBook structure
        new_tag = f'<figure><img src="{dots}.gitbook/assets/{base_name}_{idx}.png" alt=""><figcaption></figcaption></figure>'
        content = content.replace(match.group(0), new_tag)
    
    return content, replacements

# Start processing
try:
    current_dir = os.getcwd()
    image_replacements = []
    md_files_with_errors = set()
    
    # Process all markdown files
    for md_file in get_markdown_files(current_dir):
        print(f"Processing: {md_file}")
        new_content, replacements = process_markdown_file(md_file)
        
        with open(md_file, 'w', encoding='utf-8') as f:
            f.write(new_content)
        
        image_replacements.extend(replacements)
    
    assets_dir = os.path.join(current_dir, '.gitbook', 'assets')
    if os.path.exists(assets_dir):
        print("\nProcessing images in .gitbook/assets")
        temp_dir = os.path.join(assets_dir, 'temp')
        os.makedirs(temp_dir, exist_ok=True)
        
        # Process each image replacement
        for old_path, base_name, new_name, source_md in image_replacements:
            old_file = os.path.join(assets_dir, os.path.basename(old_path))
            if os.path.exists(old_file):
                new_file = os.path.join(temp_dir, new_name)
                shutil.copy2(old_file, new_file)
                print(f"Renamed: {os.path.basename(old_file)} -> {new_name}")
            else:
                rel_md_path = os.path.relpath(source_md, current_dir)
                md_files_with_errors.add((rel_md_path, old_path))
        
        # Remove old images
        for file in os.listdir(assets_dir):
            if file.endswith('.png'):
                try:
                    os.remove(os.path.join(assets_dir, file))
                except Exception as e:
                    print(f"Warning: Could not remove {file}: {str(e)}")
        
        # Move new images
        for file in os.listdir(temp_dir):
            try:
                shutil.move(os.path.join(temp_dir, file), os.path.join(assets_dir, file))
            except Exception as e:
                print(f"Warning: Could not move {file}: {str(e)}")
        
        # Clean up temp directory
        try:
            os.rmdir(temp_dir)
        except Exception as e:
            print(f"Warning: Could not remove temp directory: {str(e)}")
        
        # Print summary of errors
        if md_files_with_errors:
            print("\nMissing image references found in these files:")
            for rel_md_path, image_path in sorted(md_files_with_errors):
                print(f"\nFile: {rel_md_path}")
                print(f"Missing image: {image_path}")
                
except Exception as e:
    print(f"Error occurred: {str(e)}")
# Out:
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/SUMMARY.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/time-series/institutional-1.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/time-series/time-segmentation.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/time-series/nowcasting-series.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/dashboard-examples/turing-risk-index.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/dashboard-examples/bankruptcy-prediction.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/idna-3.10.dist-info/LICENSE.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd_plugins/extensions/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/soupsieve-2.6.dist-info/licenses/LICENSE.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/httpx-0.27.2.dist-info/licenses/LICENSE.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/pyzmq-26.2.0.dist-info/licenses/LICENSE.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/jupyter_server/i18n/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/nbconvert/templates/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/nbconvert/templates/skeleton/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/zmq/backend/cffi/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/.venv/lib/python3.12/site-packages/httpcore-1.0.6.dist-info/licenses/LICENSE.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/feature-processing/extract-features.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/feature-processing/feature-importance.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/feature-processing/neutralize-features.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/feature-processing/select-features.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/feature-processing/dimensionality-reduction.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/economic-datasets/etf-flows.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/economic-datasets/core-economic-data.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/economic-datasets/asset-rotation.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/economic-datasets/government-traffic.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/economic-datasets/turing-risk-index.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/economic-datasets/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/sectorial-datasets/box-office-stats.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/sectorial-datasets/request-datasets.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/sectorial-datasets/airbnb-data.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/sectorial-datasets/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/sectorial-datasets/phrama-clinical-trials.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/sectorial-datasets/cfpb-complaints.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/factor-signals.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/government-contracts.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/congressional-data.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/wikipedia-views.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/earnings-surprise.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/price-breakout.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/risk-indicators.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/liquidity-data.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/sec-edgar-search.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/lobbying-data.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/README.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/institutional-trading.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/financial-ratios.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/short-selling.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/employee-visa.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/insider-flow-prediction.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/accounting-data.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/sec-10k-filings.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/bankruptcy-predictions.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/realtime-datasets/equity-datasets/news-sentiment.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/pattern-recognition/pairwise-distance.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/pattern-recognition/anomaly-detection.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/pattern-recognition/clustering-panels.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/asset-managment/weight-optimization.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/asset-managment/screens-and-filters.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/asset-managment/signal-evaluation.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/get-started/release-notes.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/get-started/quickstart.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/get-started/tutorials.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/get-started/about.md
# Processing: /Users/dereksnow/Downloads/sovai-docs/sovai-documentation/get-started/installation.md
#
# Processing images in .gitbook/assets
# Renamed: image (88).png -> institutional_1_1.png
# Renamed: image (89).png -> institutional_1_2.png
# Renamed: image (5).png -> time_segmentation_1.png
# Renamed: image (1) (1) (1) (1).png -> time_segmentation_2.png
# Renamed: image (2) (1) (1).png -> time_segmentation_3.png
# Renamed: image (3) (1).png -> time_segmentation_4.png
# Renamed: image (4) (1).png -> time_segmentation_5.png
# Renamed: image (5) (1).png -> time_segmentation_6.png
# Renamed: image (97).png -> nowcasting_series_1.png
# Renamed: image (112).png -> turing_risk_index_1.png
# Renamed: risk-2.png -> turing_risk_index_2.png
# Renamed: risk_forecast (1).png -> turing_risk_index_3.png
# Renamed: risk_dash (2).png -> turing_risk_index_4.png
# Renamed: bankruptcy_one.png -> bankruptcy_prediction_1.png
# Renamed: bankruptcy_2 (2).png -> bankruptcy_prediction_2.png
# Renamed: SOVAI.png -> bankruptcy_prediction_3.png
# Renamed: image (77).png -> extract_features_1.png
# Renamed: image (95).png -> feature_importance_1.png
# Renamed: image (96).png -> feature_importance_2.png
# Renamed: image (93).png -> neutralize_features_1.png
# Renamed: image (147).png -> core_economic_data_1.png
# Renamed: image (114).png -> asset_rotation_1.png
# Renamed: image (115).png -> asset_rotation_2.png
# Renamed: image (116).png -> government_traffic_1.png
# Renamed: image (11) (1) (1) (1).png -> turing_risk_index_1.png
# Renamed: image (14) (1) (1).png -> turing_risk_index_2.png
# Renamed: image (1) (1) (1) (1) (1) (1) (1).png -> box_office_stats_1.png
# Renamed: image.png -> phrama_clinical_trials_1.png
# Renamed: image (4) (1) (1) (1) (1) (1) (1) (1) (1).png -> bankruptcy_predictions_5.png
# Renamed: image (6) (1) (1) (1) (1) (1).png -> bankruptcy_predictions_6.png
# Renamed: image (7) (1) (1) (1).png -> bankruptcy_predictions_7.png
# Renamed: image (8) (1) (1).png -> bankruptcy_predictions_8.png
# Renamed: image (9) (1) (1).png -> bankruptcy_predictions_9.png
# Renamed: image (10) (1) (1).png -> bankruptcy_predictions_10.png
# Renamed: image (12) (1) (1).png -> bankruptcy_predictions_11.png
# Renamed: image (14) (1).png -> bankruptcy_predictions_12.png
# Renamed: image (15) (1).png -> bankruptcy_predictions_13.png
# Renamed: image (11) (1) (1).png -> bankruptcy_predictions_14.png
# Renamed: image (4).png -> news_sentiment_1.png
# Renamed: image (1) (1) (1).png -> news_sentiment_2.png
# Renamed: image (1) (1).png -> news_sentiment_3.png
# Renamed: image (2) (1).png -> news_sentiment_4.png
# Renamed: image (26).png -> pairwise_distance_1.png
# Renamed: image (1) (1) (1) (1) (1) (1).png -> pairwise_distance_2.png
# Renamed: image (2) (1) (1) (1) (1).png -> anomaly_detection_1.png
# Renamed: image (3) (1) (1) (1).png -> anomaly_detection_2.png
# Renamed: image (5) (1) (1) (1).png -> anomaly_detection_3.png
# Renamed: image (6) (1) (1).png -> anomaly_detection_4.png
# Renamed: image (100).png -> clustering_panels_1.png
# Renamed: image (105).png -> clustering_panels_2.png
# Renamed: image (106).png -> clustering_panels_3.png
# Renamed: image (109).png -> clustering_panels_4.png
# Renamed: image (110).png -> clustering_panels_5.png
# Renamed: image (111).png -> clustering_panels_6.png
# Renamed: image (11).png -> weight_optimization_1.png
# Renamed: image (12).png -> weight_optimization_2.png
# Renamed: image (13).png -> weight_optimization_3.png
# Renamed: image (14).png -> weight_optimization_4.png
# Renamed: image (15).png -> weight_optimization_5.png
# Renamed: image (16).png -> weight_optimization_6.png
# Renamed: image (17).png -> weight_optimization_7.png
# Renamed: image (18).png -> weight_optimization_8.png
# Renamed: image (19).png -> weight_optimization_9.png
# Renamed: image (20).png -> weight_optimization_10.png
# Renamed: image (21).png -> weight_optimization_11.png
# Renamed: image (22).png -> weight_optimization_12.png
# Renamed: image (23).png -> weight_optimization_13.png
# Renamed: image (25).png -> weight_optimization_14.png
# Renamed: image (24).png -> weight_optimization_15.png
# Renamed: image (6).png -> signal_evaluation_1.png
# Renamed: image (1) (1) (1) (1) (1).png -> signal_evaluation_2.png
# Renamed: image (2) (1) (1) (1).png -> signal_evaluation_3.png
# Renamed: image (3) (1) (1).png -> signal_evaluation_4.png
# Renamed: image (4) (1) (1).png -> signal_evaluation_5.png
# Renamed: image (5) (1) (1).png -> signal_evaluation_6.png
# Renamed: image (6) (1).png -> signal_evaluation_7.png
# Renamed: image (7).png -> signal_evaluation_8.png
# Renamed: image (69).png -> signal_evaluation_9.png
# Renamed: image (73).png -> signal_evaluation_10.png
# Renamed: image (9).png -> signal_evaluation_11.png
# Renamed: image (55).png -> about_1.png
# Renamed: image (47).png -> about_2.png
# Renamed: image (45).png -> about_3.png
# Renamed: image (48).png -> about_4.png
# Renamed: image (53).png -> about_5.png
